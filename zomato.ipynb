# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\Ankit Kanojiya\Downloads\zomato.xlsx")

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  float64
# ...

# %%
df.drop(['url','menu_item','reviews_list'],axis=1,inplace=True)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df['rate'].replace('/5','',regex=True,inplace=True)

# %%
df['rate']
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51712    3.6
# 51713     NaN
# 51714     NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: object

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df['phone'].replace('\n',',',regex=True,inplace=True)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df['dish_liked'].fillna('No Dishes Liked',inplace=True)

# %%
df['dish_liked'].isnull().value_counts()
# Out:
# False    51717
# Name: dish_liked, dtype: int64

# %%
df['rate'].replace([np.nan,'-','NEW'],0,regex=True,inplace=True)

# %%
df['rate'].isnull().value_counts()
# Out:
# False    51717
# Name: rate, dtype: int64

# %%
nl=pd.DataFrame(df['phone'].isnull().value_counts())

# %%
nl
# Out:
#        phone
# False  50509
# True    1208

# %%
nl['nul']=nl.index

# %%
nl
# Out:
#        phone    nul
# False  50509  False
# True    1208   True

# %%
df.drop('address',axis=1,inplace=True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                          phone  \
# 0            Yes   4.1    775    080 42297555,+91 9743772233
# ...

# %%
df['phone'].isnull().value_counts()
# Out:
# False    50509
# True      1208
# Name: phone, dtype: int64

# %%
df.drop('phone',axis=1,inplace=True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
df['location'].fillna('Unknown',inplace=True)

# %%
df['location']=='Unknown'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Name: location, Length: 51717, dtype: bool

# %%
df['rest_type'].fillna('Undefined',inplace=True)

# %%
df['cuisines'].fillna('Unavailable',inplace=True)

# %%
bs=df[df['location']=='Banashankari']

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
bs
# Out:
#                         name online_order book_table  rate  votes  \
# 0                      Jalsa          Yes        Yes   4.1    775
# 1             Spice Elephant          Yes         No   4.1    787
# 2            San Churro Cafe          Yes         No   3.8    918
# 3      Addhuri Udupi Bhojana           No         No   3.7     88
# 7                     Onesta          Yes        Yes   4.6   2556
# ...                      ...          ...        ...   ...    ...
# 32994           My Tea House          Yes        Yes     0      0
# 38108     Sai Super Sandwich          Yes         No     0      0
# 38109     Sai Super Sandwich          Yes         No     0      0
# 42790     Sai Super Sandwich          Yes         No     0      0
# 47734     Sai Super Sandwich          Yes         No  3.2       7
#
#            location            rest_type  \
# 0      Banashankari        Casual Dining
# 1      Banashankari        Casual Dining
# 2      Banashankari  Cafe, Casual Dining
# ...

# %%
old=bs[bs['rate']!='NEW']

# %%
old
# Out:
#                         name online_order book_table  rate  votes  \
# 0                      Jalsa          Yes        Yes   4.1    775
# 1             Spice Elephant          Yes         No   4.1    787
# 2            San Churro Cafe          Yes         No   3.8    918
# 3      Addhuri Udupi Bhojana           No         No   3.7     88
# 7                     Onesta          Yes        Yes   4.6   2556
# ...                      ...          ...        ...   ...    ...
# 32994           My Tea House          Yes        Yes     0      0
# 38108     Sai Super Sandwich          Yes         No     0      0
# 38109     Sai Super Sandwich          Yes         No     0      0
# 42790     Sai Super Sandwich          Yes         No     0      0
# 47734     Sai Super Sandwich          Yes         No  3.2       7
#
#            location            rest_type  \
# 0      Banashankari        Casual Dining
# 1      Banashankari        Casual Dining
# 2      Banashankari  Cafe, Casual Dining
# ...

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 0, '2.9', '3.5', '2.6',
#        '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3',
#        '3.4 ', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ', '3.7 ',
#        '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ', '3.2 ',
#        '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8', '4.6 ',
#        '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ', '2.2 ',
#        '2.0 ', '1.8 '], dtype=object)

# %%
df.head(20)
# Out:
#                                                  name online_order book_table  \
# 0                                               Jalsa          Yes        Yes
# 1                                      Spice Elephant          Yes         No
# 2                                     San Churro Cafe          Yes         No
# 3                               Addhuri Udupi Bhojana           No         No
# 4                                       Grand Village           No         No
# 5                                     Timepass Dinner          Yes         No
# 6     Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                              Onesta          Yes        Yes
# 8                                      Penthouse Cafe          Yes         No
# 9                                           Smacznego          Yes         No
# 10  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# ...

# %%
df['name'].replace('CafÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â©','Cafe',inplace=True,regex=True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
df['name'][10]
# Out:
# 'Cafe Down The Alley'

# %%
df['dish_liked'][100]
# Out:
# 'Rooftop Ambience'

# %%
df[['dish1','dish2','dish3','dish4','dish5','dish6','dish7']]=df['dish_liked'].str.split(',',expand=True)

# %%
df['dish1'].replace('No Dishes Liked', 'None',inplace=True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
df[['rate','votes','approx_cost(for two people)',]]=df[['rate','votes','approx_cost(for two people)',]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         51717 non-null  float64
#  4   votes                        51717 non-null  float64
#  5   location                     51717 non-null  object
#  6   rest_type                    51717 non-null  object
#  7   dish_liked                   51717 non-null  object
#  8   cuisines                     51717 non-null  object
#  9   approx_cost(for two people)  51371 non-null  float64
#  10  listed_in(type)              51717 non-null  object
#  11  listed_in(city)              51717 non-null  object
# ...

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1  775.0                Banashankari
# ...

# %%
df['rest_type'].value_counts()
# Out:
# Quick Bites                   19132
# Casual Dining                 10330
# Cafe                           3732
# Delivery                       2604
# Dessert Parlor                 2263
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Sweet Shop, Dessert Parlor        1
# Quick Bites, Kiosk                1
# Name: rest_type, Length: 94, dtype: int64

# %%
gdf=df.groupby('location')

# %%
rt=gdf[['rate']].value_counts()

# %%
rt
# Out:
# location     rate
# BTM          0.0     1194
#              3.7      484
#              3.6      464
#              3.5      406
#              3.4      367
#                      ...
# Yeshwantpur  3.1        4
#              4.2        4
#              3.0        3
#              2.8        2
#              4.1        2
# Length: 1448, dtype: int64

# %%
rates=pd.DataFrame(rt)

# %%
rates
# Out:
#                      0
# location    rate
# BTM         0.0   1194
#             3.7    484
#             3.6    464
#             3.5    406
#             3.4    367
# ...                ...
# Yeshwantpur 3.1      4
#             4.2      4
#             3.0      3
#             2.8      2
#             4.1      2
#
# [1448 rows x 1 columns]

# %%
rates.reset_index(inplace=True)

# %%
rates
# Out:
#          location  rate  counts
# 0             BTM   0.0    1194
# 1             BTM   3.7     484
# 2             BTM   3.6     464
# 3             BTM   3.5     406
# 4             BTM   3.4     367
# ...           ...   ...     ...
# 1443  Yeshwantpur   3.1       4
# 1444  Yeshwantpur   4.2       4
# 1445  Yeshwantpur   3.0       3
# 1446  Yeshwantpur   2.8       2
# 1447  Yeshwantpur   4.1       2
#
# [1448 rows x 3 columns]

# %%
btm=rates[rates['location']=='BTM']

# %%
btm
# Out:
#    location  rate  counts
# 0       BTM   0.0    1194
# 1       BTM   3.7     484
# 2       BTM   3.6     464
# 3       BTM   3.5     406
# 4       BTM   3.4     367
# 5       BTM   3.9     351
# 6       BTM   3.8     343
# 7       BTM   3.3     260
# 8       BTM   4.0     224
# 9       BTM   3.1     221
# 10      BTM   3.2     176
# 11      BTM   4.1     120
# 12      BTM   4.2     104
# 13      BTM   3.0     103
# 14      BTM   2.9      90
# 15      BTM   2.6      55
# 16      BTM   4.5      46
# 17      BTM   2.7      29
# 18      BTM   4.4      26
# 19      BTM   2.8      26
# 20      BTM   4.3      10
# 21      BTM   2.5      10
# 22      BTM   4.9       7
# 23      BTM   2.4       6
# 24      BTM   4.6       2

# %%
sum(btm['counts'])
# Out:
# 5124

# %%
rates=rates.rename(columns={0:'counts'})

# %%
totalvotes=gdf[['votes']].sum()

# %%
totalvotes.reset_index(inplace=True)

# %%
totalvotes
# Out:
#              location     votes
# 0                 BTM  619376.0
# 1        Banashankari  162374.0
# 2           Banaswadi   35657.0
# 3   Bannerghatta Road  219077.0
# 4        Basavanagudi   94919.0
# ..                ...       ...
# 89     West Bangalore    1110.0
# 90         Whitefield  466829.0
# 91      Wilson Garden    7341.0
# 92          Yelahanka     189.0
# 93        Yeshwantpur    6980.0
#
# [94 rows x 2 columns]

# %%
plt.figure(figsize=(5,8))
plt.pie(df['online_order'].value_counts(),autopct='%.2f%%')
plt.title('Hotels having online order facility')
plt.legend(labels=df['online_order'].value_counts().index)

# %%
onl=df[df['online_order']=='Yes']

# %%
onl
# Out:
#                            name online_order book_table  rate   votes  \
# 0                         Jalsa          Yes        Yes   4.1   775.0
# 1                Spice Elephant          Yes         No   4.1   787.0
# 2               San Churro Cafe          Yes         No   3.8   918.0
# 5               Timepass Dinner          Yes         No   3.8   286.0
# 7                        Onesta          Yes        Yes   4.6  2556.0
# ...                         ...          ...        ...   ...     ...
# 51697  Shizusan Shophouse & Bar          Yes        Yes   4.4  1313.0
# 51699        Harry's Bar + Cafe          Yes        Yes   4.1  1218.0
# 51701             The Beer Cafe          Yes        Yes   4.1   673.0
# 51703      Oliver's Pub & Diner          Yes        Yes   3.9   548.0
# 51705        Izakaya Gastro Pub          Yes        Yes   3.8   128.0
#
#            location            rest_type  \
# 0      Banashankari        Casual Dining
# ...

# %%
onlr=pd.DataFrame(onl['rest_type'].value_counts()).reset_index().rename(columns={'index':'restype','rest_type':'counts'})

# %%
onlr
# Out:
#                       restype  counts
# 0                 Quick Bites   11080
# 1               Casual Dining    7032
# 2                        Cafe    2279
# 3                    Delivery    1737
# 4              Dessert Parlor    1518
# ..                        ...     ...
# 69      Dessert Parlor, Kiosk       2
# 70  Food Court, Beverage Shop       2
# 71      Bakery, Beverage Shop       1
# 72     Quick Bites, Meat Shop       1
# 73         Bakery, Food Court       1
#
# [74 rows x 2 columns]

# %%
sns.barplot(data=onlr.head(10),x='restype',y='counts')
plt.xticks(rotation=90)
plt.xlabel('Restaurant Types')
plt.ylabel('Counts')
plt.grid()
plt.title('Top 10 restaurant types having online order facility')
# Out:
# Text(0.5, 1.0, 'Top 10 restaurant types having online order facility')

# %%
qb=df[df['rest_type']=='Quick Bites']

# %%
qb
# Out:
#                                name online_order book_table  rate  votes  \
# 3             Addhuri Udupi Bhojana           No         No   3.7   88.0
# 31                       Foodiction          Yes         No   2.8  506.0
# 34                           Faasos          Yes         No   4.2  415.0
# 36                   Fast And Fresh          Yes         No   2.8   91.0
# 39     Maruthi Davangere Benne Dosa          Yes         No   4.0   17.0
# ...                             ...          ...        ...   ...    ...
# 51641                 Andhra Spices           No         No   3.2    4.0
# 51642        Basaveshwara Khanavali           No         No   0.0    0.0
# 51643             New Ambur Biryani           No         No   0.0    0.0
# 51644                Punjabi Thadka           No         No   0.0    0.0
# 51645                     Raapchick          Yes         No   3.6   49.0
#
#            location    rest_type  \
# 3      Banashankari  Quick Bites
# ...

# %%
qbd=pd.DataFrame(qb['location'].value_counts()).reset_index().rename(columns={'index':'loct','location':'counts'}).head(10)

# %%
qbd
# Out:
#                     loct  counts
# 0                    BTM    2733
# 1                    HSR     932
# 2           Marathahalli     746
# 3              Jayanagar     733
# 4             Whitefield     721
# 5               JP Nagar     700
# 6      Bannerghatta Road     646
# 7  Koramangala 1st Block     619
# 8  Koramangala 5th Block     592
# 9        Electronic City     562

# %%
plt.title('Location of quick bites restaurants located in each location')
sns.barplot(data=qbd,y='loct',x='counts')
plt.xlabel('Location')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
btm=qb['approx_cost(for two people)'].value_counts()
# Out:
# 300.0     4961
# 400.0     3256
# 200.0     3026
# 250.0     1936
# 500.0     1442
# 150.0     1246
# 350.0     1194
# 100.0      587
# 600.0      546
# 450.0      489
# 800.0       73
# 700.0       73
# 550.0       62
# 650.0       48
# 750.0       41
# 120.0       22
# 1000.0      12
# 40.0         8
# 900.0        8
# 850.0        7
# 80.0         4
# 70.0         3
# 140.0        2
# 180.0        1
# 160.0        1
# Name: approx_cost(for two people), dtype: int64

# %%
btm=qb[qb['location']=='BTM']

# %%
btm
# Out:
#                           name online_order book_table  rate  votes location  \
# 928        Hiyar Majhe Kolkata          Yes         No   4.0  244.0      BTM
# 932          Sri Lakshmi Dhaba          Yes         No   2.9  255.0      BTM
# 934             Swadista Aahar          Yes         No   4.1  775.0      BTM
# 939                   YummRajj          Yes         No   3.3   42.0      BTM
# 940             Swad Punjab Da          Yes         No   4.0  126.0      BTM
# ...                        ...          ...        ...   ...    ...      ...
# 37535            Krishna Sagar          Yes         No   3.9   52.0      BTM
# 37537              Hotel Sekar          Yes         No   0.0    0.0      BTM
# 37538          Malabar Kitchen          Yes         No   0.0    0.0      BTM
# 42545  Sri Srinivas Park Hotel          Yes         No   0.0    0.0      BTM
# 45106  Sri Srinivas Park Hotel          Yes         No   0.0    0.0      BTM
#
# ...

# %%
btm1=pd.DataFrame(btm['approx_cost(for two people)'].value_counts()).reset_index().rename(columns={'index':'appcost','approx_cost(for two people)':'counts'})

# %%
btm1
# Out:
#     appcost  counts
# 0     300.0     918
# 1     400.0     521
# 2     200.0     339
# 3     250.0     313
# 4     500.0     171
# 5     350.0     164
# 6     150.0     104
# 7     100.0      52
# 8     600.0      43
# 9     450.0      20
# 10    700.0      15
# 11    650.0      12
# 12   1000.0      12
# 13    550.0       9
# 14    800.0       9
# 15    120.0       8
# 16    850.0       7
# 17     70.0       3

# %%
btm1['appcost']=btm1['appcost'].astype(int)

# %%
btm1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   appcost  18 non-null     float64
#  1   counts   18 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 416.0 bytes

# %%
plt.grid()
sns.lineplot(data=btm1,x='appcost',y='counts')
plt.xticks([100,200,300,400,500,600,700,800,900,1000])
plt.xlabel('Approx Cost for Two People')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
ac=btm[btm['approx_cost(for two people)']==300]

# %%
ac
# Out:
#                           name online_order book_table  rate  votes location  \
# 934             Swadista Aahar          Yes         No   4.1  775.0      BTM
# 942                  Roti Wala          Yes         No   4.0  197.0      BTM
# 947           Paratha Junction          Yes         No   2.9  172.0      BTM
# 954                Litti Twist          Yes         No   4.1  464.0      BTM
# 960           Bathinda Tandoor          Yes         No   0.0    0.0      BTM
# ...                        ...          ...        ...   ...    ...      ...
# 37532   Nammura Donne Biriyani          Yes         No   3.6   68.0      BTM
# 37535            Krishna Sagar          Yes         No   3.9   52.0      BTM
# 37538          Malabar Kitchen          Yes         No   0.0    0.0      BTM
# 42545  Sri Srinivas Park Hotel          Yes         No   0.0    0.0      BTM
# 45106  Sri Srinivas Park Hotel          Yes         No   0.0    0.0      BTM
#
# ...

# %%
plt.title('Restaurants listed in type with approx cost for two people of Rs.300')
plt.pie(ac['listed_in(type)'].value_counts(),labels=ac['listed_in(type)'].value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2afa5433820>,
# ...
#  [Text(-0.23532647832366366, 1.0745331305268269, 'Delivery'),
#   Text(0.2353265789287153, -1.0745331084939669, 'Dine-out')],
#  [Text(-0.1283598972674529, 0.58610898028736, '56.9%'),
#   Text(0.1283599521429356, -0.5861089682694365, '43.1%')])

# %%
k0_3=ac[ac['listed_in(type)']=='Delivery']

# %%
k0_3
# Out:
#                                  name online_order book_table  rate  votes  \
# 934                    Swadista Aahar          Yes         No   4.1  775.0
# 942                         Roti Wala          Yes         No   4.0  197.0
# 947                  Paratha Junction          Yes         No   2.9  172.0
# 954                       Litti Twist          Yes         No   4.1  464.0
# 960                  Bathinda Tandoor          Yes         No   0.0    0.0
# ...                               ...          ...        ...   ...    ...
# 36353  Pakiza Dilli Darbar Restaurant          Yes         No   3.2   13.0
# 36375                    Biryani Spot          Yes         No   3.5    9.0
# 36376                        FoodNite          Yes         No   0.0    0.0
# 42545         Sri Srinivas Park Hotel          Yes         No   0.0    0.0
# 45106         Sri Srinivas Park Hotel          Yes         No   0.0    0.0
#
#       location    rest_type  \
# 934        BTM  Quick Bites
# ...

# %%
ct=pd.DataFrame(k0_3['listed_in(city)'].value_counts()).reset_index().rename(columns={'index':'city','listed_in(city)':'counts'})

# %%
ct
# Out:
#                      city  counts
# 0                     BTM      95
# 1   Koramangala 7th Block      88
# 2   Koramangala 5th Block      83
# 3               Jayanagar      66
# 4   Koramangala 6th Block      52
# 5   Koramangala 4th Block      50
# 6                JP Nagar      46
# 7       Bannerghatta Road      35
# 8            Basavanagudi       4
# 9                     HSR       1
# 10                MG Road       1
# 11       Old Airport Road       1

# %%
sns.barplot(data=ct,y='city',x='counts')
plt.title('Most number of city listed with approx cost for two people of Rs.300')
# Out:
# Text(0.5, 1.0, 'Most number of city listed with approx cost for two people of Rs.300')
